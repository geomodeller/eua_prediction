# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt

# Check if GPU is available
import torch 
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Load data

# %%
df_all = pd.read_csv('eua_price_data_High_Low.csv', thousands=',') 
df_all['Date'] = pd.to_datetime(df_all['Date'], format='%Y-%m-%d')  
df_all = df_all.sort_values(by = 'Date', ascending=True).reset_index(drop = True)
df_all = df_all[(df_all['Date'] > pd.to_datetime('2020-11-24'))].reset_index(drop=True)

# %% [markdown]
# # Preprocessing & train/test data split

# %%
from script.curate_training_test_data import  curate_training_test_data_many

predictors_lst =['EUA','Oil', 'Coal','Power', 'GDP', 'S&P_clean', 'High_price', 'Low_price']
test_date = '2024-07-23' 

folder_name = "result_nn_pytorch_multisteps"
modeltype = 'denselayer_v2'
if os.path.isdir(folder_name) is not True:
    os.mkdir(folder_name)
sequence_length = 28
checkpoint_path = f"./{folder_name}/{modeltype}_ts_{sequence_length}.pth"

last_train_date = pd.to_datetime(test_date) - pd.to_timedelta(1, unit = 'day')
X_train, y_train, X_test, y_test, scaler = curate_training_test_data_many(
                                            df_all, 
                                            flatten=True,
                                            sequence_length_input=28,  # 입력 시퀀스 길이 (30일)
                                            sequence_length_out=28,    # 입력 시퀀스 길이 (30일)
                                            test_date=test_date,
                                            predictors_lst=predictors_lst,
                                            dtype = 'float32',
                                            is_test_split = True,
                                        )

# Convert to PyTorch tensor
X_train_tensor, y_train_tensor = torch.from_numpy(X_train).to(device), torch.from_numpy(y_train).to(device)
X_test_tensor, y_test_tensor = torch.from_numpy(X_test).to(device), torch.from_numpy(y_test).to(device)

# %%
from script.generate_DenseLayer_torch import generate_nn_multi_step, train_NN
model = generate_nn_multi_step(X_train_tensor, y_train_tensor)

if os.path.isfile('best_mutistep_nn_model.pth'):
    model.load_state_dict(torch.load('best_mutistep_nn_model.pth'))
else:
    history = train_NN(model, 
                       checkpoint_path, 
                        X_train_tensor, y_train_tensor, 
                        X_test_tensor, y_test_tensor,
                        patience=5000,
                        batch_size=129, # batch should not be 128!! 
                        epochs=5000, verbose=100)
# Out:
# Model checkpoint saved at epoch 50
# Epoch [100/5000], Train Loss: 0.8320, Val Loss: 0.4580
# Model checkpoint saved at epoch 100
# Model checkpoint saved at epoch 150
# Epoch [200/5000], Train Loss: 0.5378, Val Loss: 0.2551
# Model checkpoint saved at epoch 200
# Model checkpoint saved at epoch 250
# Epoch [300/5000], Train Loss: 0.3648, Val Loss: 0.1475
# Model checkpoint saved at epoch 300
# Model checkpoint saved at epoch 350
# Epoch [400/5000], Train Loss: 0.2722, Val Loss: 0.0961
# Model checkpoint saved at epoch 400
# Model checkpoint saved at epoch 450
# Epoch [500/5000], Train Loss: 0.2191, Val Loss: 0.0765
# Model checkpoint saved at epoch 500
# Model checkpoint saved at epoch 550
# Epoch [600/5000], Train Loss: 0.1886, Val Loss: 0.0690
# Model checkpoint saved at epoch 600
# Model checkpoint saved at epoch 650
# Epoch [700/5000], Train Loss: 0.1626, Val Loss: 0.0655
# Model checkpoint saved at epoch 700
# Model checkpoint saved at epoch 750
# Epoch [800/5000], Train Loss: 0.1447, Val Loss: 0.0626
# Model checkpoint saved at epoch 800
# Model checkpoint saved at epoch 850
# Epoch [900/5000], Train Loss: 0.1303, Val Loss: 0.0608
# Model checkpoint saved at epoch 900
# Model checkpoint saved at epoch 950
# Epoch [1000/5000], Train Loss: 0.1178, Val Loss: 0.0595
# Model checkpoint saved at epoch 1000
# Model checkpoint saved at epoch 1050
# Epoch [1100/5000], Train Loss: 0.1094, Val Loss: 0.0578
# Model checkpoint saved at epoch 1100
# Model checkpoint saved at epoch 1150
# Epoch [1200/5000], Train Loss: 0.1024, Val Loss: 0.0569
# Model checkpoint saved at epoch 1200
# Model checkpoint saved at epoch 1250
# Epoch [1300/5000], Train Loss: 0.0969, Val Loss: 0.0558
# Model checkpoint saved at epoch 1300
# Model checkpoint saved at epoch 1350
# Epoch [1400/5000], Train Loss: 0.0907, Val Loss: 0.0551
# Model checkpoint saved at epoch 1400
# Model checkpoint saved at epoch 1450
# Epoch [1500/5000], Train Loss: 0.0859, Val Loss: 0.0540
# Model checkpoint saved at epoch 1500
# Model checkpoint saved at epoch 1550
# Epoch [1600/5000], Train Loss: 0.0813, Val Loss: 0.0534
# Model checkpoint saved at epoch 1600
# Model checkpoint saved at epoch 1650
# Epoch [1700/5000], Train Loss: 0.0796, Val Loss: 0.0532
# Model checkpoint saved at epoch 1700
# Model checkpoint saved at epoch 1750
# Epoch [1800/5000], Train Loss: 0.0770, Val Loss: 0.0526
# Model checkpoint saved at epoch 1800
# Model checkpoint saved at epoch 1850
# Epoch [1900/5000], Train Loss: 0.0721, Val Loss: 0.0512
# Model checkpoint saved at epoch 1900
# Model checkpoint saved at epoch 1950
# Epoch [2000/5000], Train Loss: 0.0695, Val Loss: 0.0513
# Model checkpoint saved at epoch 2000
# Model checkpoint saved at epoch 2050
# Epoch [2100/5000], Train Loss: 0.0668, Val Loss: 0.0516
# Model checkpoint saved at epoch 2100
# Model checkpoint saved at epoch 2150
# Epoch [2200/5000], Train Loss: 0.0649, Val Loss: 0.0506
# Model checkpoint saved at epoch 2200
# Model checkpoint saved at epoch 2250
# Epoch [2300/5000], Train Loss: 0.0635, Val Loss: 0.0505
# Model checkpoint saved at epoch 2300
# Model checkpoint saved at epoch 2350
# Epoch [2400/5000], Train Loss: 0.0636, Val Loss: 0.0500
# Model checkpoint saved at epoch 2400
# Model checkpoint saved at epoch 2450
# Epoch [2500/5000], Train Loss: 0.0621, Val Loss: 0.0517
# Model checkpoint saved at epoch 2500
# Model checkpoint saved at epoch 2550
# Epoch [2600/5000], Train Loss: 0.0580, Val Loss: 0.0501
# Model checkpoint saved at epoch 2600
# Model checkpoint saved at epoch 2650
# Epoch [2700/5000], Train Loss: 0.0559, Val Loss: 0.0509
# Model checkpoint saved at epoch 2700
# Model checkpoint saved at epoch 2750
# Epoch [2800/5000], Train Loss: 0.0559, Val Loss: 0.0503
# Model checkpoint saved at epoch 2800
# Model checkpoint saved at epoch 2850
# Epoch [2900/5000], Train Loss: 0.0544, Val Loss: 0.0497
# Model checkpoint saved at epoch 2900
# Model checkpoint saved at epoch 2950
# Epoch [3000/5000], Train Loss: 0.0537, Val Loss: 0.0503
# Model checkpoint saved at epoch 3000
# Model checkpoint saved at epoch 3050
# Epoch [3100/5000], Train Loss: 0.0521, Val Loss: 0.0500
# Model checkpoint saved at epoch 3100
# Model checkpoint saved at epoch 3150
# Epoch [3200/5000], Train Loss: 0.0508, Val Loss: 0.0502
# Model checkpoint saved at epoch 3200
# Model checkpoint saved at epoch 3250
# Epoch [3300/5000], Train Loss: 0.0497, Val Loss: 0.0505
# Model checkpoint saved at epoch 3300
# Model checkpoint saved at epoch 3350
# Epoch [3400/5000], Train Loss: 0.0483, Val Loss: 0.0498
# Model checkpoint saved at epoch 3400
# Model checkpoint saved at epoch 3450
# Epoch [3500/5000], Train Loss: 0.0482, Val Loss: 0.0505
# Model checkpoint saved at epoch 3500
# Model checkpoint saved at epoch 3550
# Epoch [3600/5000], Train Loss: 0.0479, Val Loss: 0.0494
# Model checkpoint saved at epoch 3600
# Model checkpoint saved at epoch 3650
# Epoch [3700/5000], Train Loss: 0.0475, Val Loss: 0.0502
# Model checkpoint saved at epoch 3700
# Model checkpoint saved at epoch 3750
# Epoch [3800/5000], Train Loss: 0.0457, Val Loss: 0.0512
# Model checkpoint saved at epoch 3800
# Model checkpoint saved at epoch 3850
# Epoch [3900/5000], Train Loss: 0.0450, Val Loss: 0.0517
# Model checkpoint saved at epoch 3900
# Model checkpoint saved at epoch 3950
# Epoch [4000/5000], Train Loss: 0.0452, Val Loss: 0.0513
# Model checkpoint saved at epoch 4000
# Model checkpoint saved at epoch 4050
# Epoch [4100/5000], Train Loss: 0.0447, Val Loss: 0.0510
# Model checkpoint saved at epoch 4100
# Model checkpoint saved at epoch 4150
# Epoch [4200/5000], Train Loss: 0.0436, Val Loss: 0.0511
# Model checkpoint saved at epoch 4200
# Model checkpoint saved at epoch 4250
# Epoch [4300/5000], Train Loss: 0.0436, Val Loss: 0.0523
# Model checkpoint saved at epoch 4300
# Model checkpoint saved at epoch 4350
# Epoch [4400/5000], Train Loss: 0.0430, Val Loss: 0.0508
# Model checkpoint saved at epoch 4400
# Model checkpoint saved at epoch 4450
# Epoch [4500/5000], Train Loss: 0.0427, Val Loss: 0.0525
# Model checkpoint saved at epoch 4500
# Model checkpoint saved at epoch 4550
# Epoch [4600/5000], Train Loss: 0.0413, Val Loss: 0.0519
# Model checkpoint saved at epoch 4600
# Model checkpoint saved at epoch 4650
# Epoch [4700/5000], Train Loss: 0.0411, Val Loss: 0.0531
# Model checkpoint saved at epoch 4700
# Model checkpoint saved at epoch 4750
# Epoch [4800/5000], Train Loss: 0.0406, Val Loss: 0.0527
# Model checkpoint saved at epoch 4800
# Model checkpoint saved at epoch 4850
# Epoch [4900/5000], Train Loss: 0.0400, Val Loss: 0.0539
# Model checkpoint saved at epoch 4900
# Model checkpoint saved at epoch 4950
# Epoch [5000/5000], Train Loss: 0.0407, Val Loss: 0.0512
# Model checkpoint saved at epoch 5000

# %%
## visualize loss curve plot
plt.figure(figsize=(10, 5))
plt.plot(history['train_loss'], label='Training Loss')
plt.plot(history['val_loss'], label='Validation Loss')
a = np.array(history['val_loss'])
plt.axvline(np.where(a==a.min())[0][0], color = 'red')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Validation Loss Over Epochs')
# plt.ylim([0,5])
plt.yscale('log')
plt.legend()
plt.grid('on')
plt.show()

# %%
# prediction for train/validation data
model.to('cpu') # model.to('cuda')  

model.eval()
y_train_pred = model(X_train_tensor.cpu()).detach().numpy()
y_test_pred = model(X_test_tensor.cpu()).detach().numpy()

y_test_preds = []
model.train()
for i in range(10):
    y_test_preds.append(model(X_test_tensor.cpu()).detach().numpy())

# %%
# # prediction for train/validation data
# model.to('cuda') # model.to('cuda')  
# train_size = int((1 - 0.05) * X_train_tensor.size(0))
# y_train_true, y_test_true = y_train[:train_size], y_train[train_size:]

# model.eval()
# y_train_pred = model(X_train_tensor[:train_size]).detach().cpu().numpy()
# y_test_pred = model(X_train_tensor[train_size:]).detach().cpu().numpy()

# y_test_preds = []
# model.train()
# for i in range(10):
#     y_test_preds.append(model(X_train_tensor[train_size:]).detach().cpu().numpy())

# %%
from script.post_processing import inverse_scaler_of_all_var
y_train_pred = inverse_scaler_of_all_var(y_train_pred, scaler).reshape(-1,sequence_length,len(predictors_lst))
y_test_pred  = inverse_scaler_of_all_var(y_test_pred, scaler).reshape(-1,sequence_length,len(predictors_lst))
y_test_preds = [i.reshape(-1,sequence_length,len(predictors_lst)) for i in inverse_scaler_of_all_var(y_test_preds, scaler)]
y_train_true = inverse_scaler_of_all_var(y_train, scaler).reshape(-1,sequence_length,len(predictors_lst))
y_test_true  = inverse_scaler_of_all_var(y_test, scaler).reshape(-1,sequence_length,len(predictors_lst))

# %%
# define start of train date and valid/train split date
train_start_date =  df_all['Date'][0] + pd.to_timedelta(28, unit = 'day')
train_test_split_date = pd.to_datetime(test_date)

# %%
# visuals of train/validation data prediction (single prediction)
from script.post_processing import visual_train_n_valid_data_performance
visual_train_n_valid_data_performance(y_train_pred,y_test_pred, 
                                      train_start_date, train_test_split_date, df_all,
                                      decoration = {'xlabel': 'Time', 
                                                    'ylabel':'EUA', 
                                                    'title':'EUA prediction result',
                                                    'grid':'on'})

# %%
# visual ensemble of predictions
visual_train_n_valid_data_performance(y_train_pred,y_test_preds, train_start_date, train_test_split_date, df_all,
                                      figsize = (10,3),
                                      index_of_data = 0,
                                      name_of_data = 'EUA',
                                      decoration = {'xlabel': 'Time', 
                                                    'ylabel':'EUA', 
                                                    'title':'EUA prediction result',
                                                    'grid':'on'})

# %%
# for i, name in enumerate(['EUA','Oil', 'Coal','Power', 'GDP', 'S&P_clean',]):
#     visual_train_n_valid_data_performance(y_train_pred,y_test_preds, train_start_date, train_test_split_date, df_all,
#                                         figsize = (10,3),
#                                         index_of_data = i,
#                                         name_of_data = name,
#                                         decoration = {'xlabel': 'Time', 
#                                                         'ylabel':name, 
#                                                         'title':f'{name} prediction result',
#                                                         'grid':'on'})

# %%
shape
# Out:
# torch.Size([1, 224])

# %%
# 2. add recursive scheme
from script.post_processing import resursive_furture_prediction_with_dropout_in_cpu
future_price_ensemble, future_time = resursive_furture_prediction_with_dropout_in_cpu(model, 
                                                                                      X_test_tensor[-1],
                                                                                        train_test_split_date = df_all['Date'].max(),
                                                                                        num_of_ensemble = 100,
                                                                                        scaler = scaler,
                                                                                        df_all = df_all,
                                                                                        flatten  = True)

# %%
from script.post_processing import visual_recursive_future_prediction_plotly
visual_recursive_future_prediction_plotly(future_time, future_price_ensemble,
                                       train_test_split_date,
                                       df_all,
                                          
                                          index_of_data= 0, # 0 is EUA price
                                          name_of_data = 'EUA',
                                        decoration = {'xlabel': 'Time', 
                                                        'ylabel':'EUA', 
                                                        'title':'EUA prediction result',
                                                        'grid':'on'})
# Out:
# c:\Users\DELL\AppData\Local\Programs\Python\Python311\Lib\site-packages\_plotly_utils\basevalidators.py:105: FutureWarning:
#
# The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result

# %%
from script.post_processing import visual_recursive_future_prediction
for i, name in enumerate(['EUA','Oil', 'Coal','Power', 'GDP', 'S&P_clean',]):
    visual_recursive_future_prediction(future_time, future_price_ensemble,
                                       train_test_split_date,
                                       df_all,
                                          figsize = (10,3),
                                          index_of_data= i, # 0 is EUA price
                                          name_of_data = name,
                                        decoration = {'xlabel': 'Time', 
                                                        'ylabel':name, 
                                                        'title':f'{name} prediction result',
                                                        'grid':'on'})
